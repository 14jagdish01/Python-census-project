# %%
import pandas as pd 
import numpy as  np
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib import style

# %%
df=pd.read_csv("C:\\Users\\Mukesh Pandey\\Downloads\\Data P3 MeriSKILL.zip")

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %% [markdown]
# # EDA

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
newdata=df[['Age','OverTime','MaritalStatus','JobRole','Gender','EducationField','Department',
           'BusinessTravel','Education','DistanceFromHome','DailyRate','Attrition']]

# %% [markdown]
# Rename columns

# %%
newdata.rename({'BusinessTravel':'Business Travel','EducationField':'Education Field',
               'MaritalStatus':'Marital Status','OverTime':'Over Time'})
# Out:
#       Age OverTime MaritalStatus                    JobRole  Gender  \
# 0      41      Yes        Single            Sales Executive  Female
# 1      49       No       Married         Research Scientist    Male
# 2      37      Yes        Single      Laboratory Technician    Male
# 3      33      Yes       Married         Research Scientist  Female
# 4      27       No       Married      Laboratory Technician    Male
# ...   ...      ...           ...                        ...     ...
# 1465   36       No       Married      Laboratory Technician    Male
# 1466   39       No       Married  Healthcare Representative    Male
# 1467   27      Yes       Married     Manufacturing Director    Male
# 1468   49       No       Married            Sales Executive    Male
# 1469   34       No       Married      Laboratory Technician    Male
#
#      EducationField              Department     BusinessTravel  Education  \
# 0     Life Sciences                   Sales      Travel_Rarely          2
# ...

# %%
newdata.isnull().count()
# Out:
# Age                 1470
# OverTime            1470
# MaritalStatus       1470
# JobRole             1470
# Gender              1470
# EducationField      1470
# Department          1470
# BusinessTravel      1470
# Education           1470
# DistanceFromHome    1470
# DailyRate           1470
# Attrition           1470
# dtype: int64

# %% [markdown]
# KPI'1'

# %%
sa_markt=newdata[(newdata['Department']=='Sales') & (newdata['EducationField']=='Marketing') ]
sa_markt
# Out:
#       Age OverTime MaritalStatus               JobRole  Gender EducationField  \
# 27     42       No       Married       Sales Executive    Male      Marketing
# 29     46       No        Single               Manager  Female      Marketing
# 36     50      Yes       Married  Sales Representative    Male      Marketing
# 37     35       No       Married  Sales Representative  Female      Marketing
# 46     34       No        Single       Sales Executive    Male      Marketing
# ...   ...      ...           ...                   ...     ...            ...
# 1446   34       No       Married       Sales Executive  Female      Marketing
# 1447   36       No      Divorced       Sales Executive    Male      Marketing
# 1453   36       No       Married       Sales Executive  Female      Marketing
# 1461   50      Yes      Divorced       Sales Executive    Male      Marketing
# 1462   39       No       Married       Sales Executive  Female      Marketing
#
# ...

# %%
sa_markt.describe()
# Out:
#               Age   Education  DistanceFromHome    DailyRate
# count  159.000000  159.000000        159.000000   159.000000
# mean    37.924528    3.125786         10.106918   727.836478
# std      9.153783    1.035705          8.174204   394.040573
# min     18.000000    1.000000          1.000000   118.000000
# 25%     31.500000    3.000000          3.000000   389.000000
# 50%     36.000000    3.000000          8.000000   685.000000
# 75%     45.000000    4.000000         15.000000  1049.500000
# max     60.000000    5.000000         29.000000  1499.000000

# %% [markdown]
# KPI'2'

# %%
newdata['BusinessTravel'].value_counts()
# Out:
# Travel_Rarely        1043
# Travel_Frequently     277
# Non-Travel            150
# Name: BusinessTravel, dtype: int64

# %%
newdata.groupby('BusinessTravel')['DailyRate'].mean()
# Out:
# BusinessTravel
# Non-Travel           816.960000
# Travel_Frequently    792.628159
# Travel_Rarely        803.022052
# Name: DailyRate, dtype: float64

# %% [markdown]
# KPI'3'

# %%
dc=newdata.groupby('Department')['OverTime'].count()
dc
# Out:
# Department
# Human Resources            63
# Research & Development    961
# Sales                     446
# Name: OverTime, dtype: int64

# %%
import matplotlib.pyplot as plt
x=['Human Resources','Research & Developmen','Sales']
y=[63,961,446]
plt.bar(x,y,color=['red','green','black'],width=0.3)
plt.show()

# %%
newdata
# Out:
#       Age OverTime MaritalStatus                    JobRole  Gender  \
# 0      41      Yes        Single            Sales Executive  Female
# 1      49       No       Married         Research Scientist    Male
# 2      37      Yes        Single      Laboratory Technician    Male
# 3      33      Yes       Married         Research Scientist  Female
# 4      27       No       Married      Laboratory Technician    Male
# ...   ...      ...           ...                        ...     ...
# 1465   36       No       Married      Laboratory Technician    Male
# 1466   39       No       Married  Healthcare Representative    Male
# 1467   27      Yes       Married     Manufacturing Director    Male
# 1468   49       No       Married            Sales Executive    Male
# 1469   34       No       Married      Laboratory Technician    Male
#
#      EducationField              Department     BusinessTravel  Education  \
# 0     Life Sciences                   Sales      Travel_Rarely          2
# ...

# %%
newdata['JobRole'].value_counts()
# Out:
# Sales Executive              326
# Research Scientist           292
# Laboratory Technician        259
# Manufacturing Director       145
# Healthcare Representative    131
# Manager                      102
# Sales Representative          83
# Research Director             80
# Human Resources               52
# Name: JobRole, dtype: int64

# %%
x=['Sales Executive','Research Scientist','Laboratory Technician','Manufacturing Director','Healthcare Representative','Manager',
  'Sales Representative','Research Director','Human Resources']
y=[326,292,259,145,131,102,83,80,52]
plt.pie(y,labels=x,explode=[1,0,0,0,0,0,0,0,0],shadow=True,autopct='%.1f%%')
plt.show()

# %%
sales_famle=newdata[(newdata['JobRole']=='Manager') & (newdata['Gender']=='Female')]
sales_famle
# Out:
#       Age OverTime MaritalStatus  JobRole  Gender    EducationField  \
# 18     53       No       Married  Manager  Female     Life Sciences
# 25     53       No      Divorced  Manager  Female             Other
# 29     46       No        Single  Manager  Female         Marketing
# 65     55      Yes      Divorced  Manager  Female           Medical
# 105    59       No       Married  Manager  Female   Human Resources
# 112    54      Yes        Single  Manager  Female   Human Resources
# 116    34       No        Single  Manager  Female           Medical
# 165    50       No        Single  Manager  Female     Life Sciences
# 186    40       No       Married  Manager  Female           Medical
# 215    41      Yes        Single  Manager  Female     Life Sciences
# 233    50       No      Divorced  Manager  Female           Medical
# 235    43      Yes       Married  Manager  Female         Marketing
# 263    46      Yes       Married  Manager  Female  Technical Degree
# ...

# %%
Female=newdata[newdata['Gender']=='Female']
Female
# Out:
#       Age OverTime MaritalStatus                 JobRole  Gender  \
# 0      41      Yes        Single         Sales Executive  Female
# 3      33      Yes       Married      Research Scientist  Female
# 6      59      Yes       Married   Laboratory Technician  Female
# 11     29      Yes        Single   Laboratory Technician  Female
# 15     29       No      Divorced  Manufacturing Director  Female
# ...   ...      ...           ...                     ...     ...
# 1457   40       No       Married      Research Scientist  Female
# 1458   35       No       Married      Research Scientist  Female
# 1460   29       No        Single      Research Scientist  Female
# 1462   39       No       Married         Sales Executive  Female
# 1464   26       No        Single    Sales Representative  Female
#
#      EducationField              Department     BusinessTravel  Education  \
# 0     Life Sciences                   Sales      Travel_Rarely          2
# ...

# %% [markdown]
# KPI'4'

# %%
Female_unmaried=Female[Female['MaritalStatus']!='Married']

# %%
Female_unmaried
# Out:
#       Age OverTime MaritalStatus                 JobRole  Gender  \
# 0      41      Yes        Single         Sales Executive  Female
# 11     29      Yes        Single   Laboratory Technician  Female
# 15     29       No      Divorced  Manufacturing Director  Female
# 20     24       No      Divorced  Manufacturing Director  Female
# 22     34       No        Single       Research Director  Female
# ...   ...      ...           ...                     ...     ...
# 1440   36       No      Divorced  Manufacturing Director  Female
# 1450   35      Yes        Single         Human Resources  Female
# 1454   45       No        Single         Sales Executive  Female
# 1460   29       No        Single      Research Scientist  Female
# 1464   26       No        Single    Sales Representative  Female
#
#      EducationField              Department     BusinessTravel  Education  \
# 0     Life Sciences                   Sales      Travel_Rarely          2
# ...

# %%
Female_unmaried['Department'].value_counts()
# Out:
# Research & Development    212
# Sales                      95
# Human Resources             9
# Name: Department, dtype: int64

# %%
import matplotlib.pyplot as plt
x=['Research & Developmen','Sales','Human Resources']
y=[212,95,9]
plt.bar(x,y,color=['red','green','black'],width=0.3)
plt.title('Female not Married in Department')
plt.show()

# %%
Female_unmaried['EducationField'].value_counts()
# Out:
# Life Sciences       132
# Medical             108
# Marketing            31
# Technical Degree     30
# Other                12
# Human Resources       3
# Name: EducationField, dtype: int64

# %%
x=['Life Sciences','Medical','Marketing','Technical Degree','Other','Human Resources']
y=[132,108,31,30,12,3]
plt.pie(y,labels=x,shadow=True,autopct='%.1f%%')
plt.title('Female not Married in Education Field')
plt.show()

# %% [markdown]
# KPI'6'

# %% [markdown]
# Avarage ages of people by gender, department,and job

# %%
newdata.groupby(['Gender','Department','JobRole'])['Age'].mean().reset_index()
# Out:
#     Gender              Department                    JobRole        Age
# 0   Female         Human Resources            Human Resources  34.437500
# 1   Female         Human Resources                    Manager  50.500000
# 2   Female  Research & Development  Healthcare Representative  38.901961
# 3   Female  Research & Development      Laboratory Technician  35.270588
# 4   Female  Research & Development                    Manager  47.500000
# 5   Female  Research & Development     Manufacturing Director  38.638889
# 6   Female  Research & Development          Research Director  41.909091
# 7   Female  Research & Development         Research Scientist  33.991228
# 8   Female                   Sales                    Manager  47.315789
# 9   Female                   Sales            Sales Executive  37.833333
# 10  Female                   Sales       Sales Representative  30.052632
# 11    Male         Human Resources            Human Resources  35.972222
# ...

# %%
df.drop_duplicates()
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
newdata
# Out:
#       Age OverTime MaritalStatus                    JobRole  Gender  \
# 0      41      Yes        Single            Sales Executive  Female
# 1      49       No       Married         Research Scientist    Male
# 2      37      Yes        Single      Laboratory Technician    Male
# 3      33      Yes       Married         Research Scientist  Female
# 4      27       No       Married      Laboratory Technician    Male
# ...   ...      ...           ...                        ...     ...
# 1465   36       No       Married      Laboratory Technician    Male
# 1466   39       No       Married  Healthcare Representative    Male
# 1467   27      Yes       Married     Manufacturing Director    Male
# 1468   49       No       Married            Sales Executive    Male
# 1469   34       No       Married      Laboratory Technician    Male
#
#      EducationField              Department     BusinessTravel  Education  \
# 0     Life Sciences                   Sales      Travel_Rarely          2
# ...

# %%
dm=newdata[(newdata['Age']>=40) & (newdata['DailyRate']>=1000) & (newdata['JobRole']=='Manager')&(newdata['Gender']=='Male')]
dm
# Out:
#       Age OverTime MaritalStatus  JobRole Gender    EducationField  \
# 194    45       No       Married  Manager   Male           Medical
# 425    50       No       Married  Manager   Male     Life Sciences
# 477    50       No       Married  Manager   Male           Medical
# 497    44      Yes       Married  Manager   Male             Other
# 699    52       No       Married  Manager   Male     Life Sciences
# 701    53       No      Divorced  Manager   Male           Medical
# 758    59      Yes       Married  Manager   Male  Technical Degree
# 804    48       No        Single  Manager   Male           Medical
# 899    49       No       Married  Manager   Male           Medical
# 907    44       No       Married  Manager   Male         Marketing
# 922    44       No      Divorced  Manager   Male     Life Sciences
# 1129   42       No        Single  Manager   Male             Other
# 1348   40       No      Divorced  Manager   Male     Life Sciences
#
# ...

# %%
dm.describe()
# Out:
#              Age  Education  DistanceFromHome    DailyRate
# count  13.000000  13.000000         13.000000    13.000000
# mean   47.692308   2.769231          5.000000  1171.307692
# std     5.218311   0.926809          7.549834   103.308103
# min    40.000000   2.000000          1.000000  1053.000000
# 25%    44.000000   2.000000          1.000000  1098.000000
# 50%    48.000000   2.000000          3.000000  1137.000000
# 75%    50.000000   4.000000          4.000000  1246.000000
# max    59.000000   4.000000         29.000000  1376.000000

# %%
md=newdata[(newdata['Age']>=20) & (newdata['DailyRate']>=1000)&(newdata['Gender']=='Male')]
md
# Out:
#       Age OverTime MaritalStatus                    JobRole Gender  \
# 2      37      Yes        Single      Laboratory Technician   Male
# 5      32       No        Single      Laboratory Technician   Male
# 7      30       No      Divorced      Laboratory Technician   Male
# 9      36       No       Married  Healthcare Representative   Male
# 13     34       No      Divorced      Laboratory Technician   Male
# ...   ...      ...           ...                        ...    ...
# 1442   29      Yes       Married         Research Scientist   Male
# 1455   40       No        Single         Research Scientist   Male
# 1456   35      Yes       Married  Healthcare Representative   Male
# 1459   29      Yes       Married      Laboratory Technician   Male
# 1468   49       No       Married            Sales Executive   Male
#
#      EducationField              Department     BusinessTravel  Education  \
# 2             Other  Research & Development      Travel_Rarely          2
# ...

# %%
newdata['MaritalStatus'].value_counts().plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='MaritalStatus'>

# %%
newdata['Attrition'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
levecom=newdata[newdata['Attrition']=='Yes']
levecom
# Out:
#       Age OverTime MaritalStatus                JobRole  Gender  \
# 0      41      Yes        Single        Sales Executive  Female
# 2      37      Yes        Single  Laboratory Technician    Male
# 14     28      Yes        Single  Laboratory Technician    Male
# 21     36       No        Single   Sales Representative    Male
# 24     34       No        Single     Research Scientist    Male
# ...   ...      ...           ...                    ...     ...
# 1438   23       No       Married   Sales Representative    Male
# 1442   29      Yes       Married     Research Scientist    Male
# 1444   56       No       Married  Laboratory Technician    Male
# 1452   50       No      Divorced        Sales Executive    Male
# 1461   50      Yes      Divorced        Sales Executive    Male
#
#         EducationField              Department     BusinessTravel  Education  \
# 0        Life Sciences                   Sales      Travel_Rarely          2
# ...

# %%
levecom.groupby(['Attrition','Department','JobRole'])['Department'].count().to_frame()
# Out:
#                                                             Department
# Attrition Department             JobRole
# Yes       Human Resources        Human Resources                    12
#           Research & Development Healthcare Representative           9
#                                  Laboratory Technician              62
#                                  Manager                             3
#                                  Manufacturing Director             10
#                                  Research Director                   2
#                                  Research Scientist                 47
#           Sales                  Manager                             2
#                                  Sales Executive                    57
#                                  Sales Representative               33

# %%
newdata[newdata['MaritalStatus']=='Divorced']['MaritalStatus'].value_counts().plot(kind='bar')
plt.title('count of people dicoved in company')
plt.show()

# %%
md['EducationField'].head(10).value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
newdata['MaritalStatus'].value_counts().plot(kind='bar')
plt.title('MaritalStatus')
plt.show()

# %%
newdata['JobRole'].value_counts().plot(kind='bar')
plt.title('JobRole')
plt.show()

# %%
newdata['BusinessTravel'].value_counts().plot(kind='bar')
plt.title('BusinessTravel')
plt.show()

# %%
df['DistanceFromHome'].hist(figsize=(6,4))
plt.show()

# %%
df['DistanceFromHome'].hist(figsize=(8,4))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7864\2414161549.py in <module>
# ----> 1 df['DistanceFromHome'].hist(figsize=(8,4))
#       2 plt.show()
#
# NameError: name 'df' is not defined
